# %%
# %pip install numpy pandas

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
np_array = np.array([11, 21, 31])
dicte = {'a': 10, 'b': 20, 'c':30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list, index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(dicte)
# Out:
# a    10
# b    20
# c    30
# dtype: int64
