# %%
# %pip install numpy pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\sunnykumar.bhakta\sunny-dev\conepts\signle\notebook\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\sunnykumar.bhakta\sunny-dev\conepts\signle\notebook\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~lotly (C:\Users\sunnykumar.bhakta\sunny-dev\conepts\signle\notebook\myenv\Lib\site-packages)
#
# [notice] A new release of pip is available: 24.2 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np 
import pandas as pd 
from rich import print

# %%
data_dict = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}

# %% [markdown]
# #### Creating a DataFrame

# %%
df = pd.DataFrame(data_dict)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]

# %%
df1 = pd.DataFrame(data_list)
df1
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df1[[1, 2]] # incase of column as index 0,1 ,2 we can use use it to extract column based on it
# Out:
#     1         2
# 0  28  New York
# 1  34     Paris
# 2  29    Berlin
# 3  42    London

# %%
df2 = pd.DataFrame(data_list, columns=columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[["Name", "City"]] # as we added label to column so index won;t work need to use Coumn Name
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #### Adding new column

# %%
df2["Designaition"] = ["Doctor", "Eng", "Mechanic", "Scienticts"]
df2
# Out:
#     Name  Age      City  Salary Designaition
# 0   John   28  New York   65000       Doctor
# 1   Anna   34     Paris   70000          Eng
# 2  Peter   29    Berlin   62000     Mechanic
# 3  Linda   42    London   85000   Scienticts

# %% [markdown]
# #### Removing rows

# %%
df2.drop([0, 1], axis=0)
# Out:
#     Name  Age    City  Salary Designaition
# 2  Peter   29  Berlin   62000     Mechanic
# 3  Linda   42  London   85000   Scienticts

# %% [markdown]
# #### Remove Columns

# %%
df2.drop(["Age", "Salary"], axis=1)
# Out:
#     Name      City Designaition
# 0   John  New York       Doctor
# 1   Anna     Paris          Eng
# 2  Peter    Berlin     Mechanic
# 3  Linda    London   Scienticts

# %% [markdown]
# #### Select row

# %%
df2.loc[[0,1]] # loc called location, used when index is number like 0, 1, 2
# Out:
#    Name  Age      City  Salary Designaition
# 0  John   28  New York   65000       Doctor
# 1  Anna   34     Paris   70000          Eng

# %%
df2
# Out:
#     Name  Age      City  Salary Designaition
# 0   John   28  New York   65000       Doctor
# 1   Anna   34     Paris   70000          Eng
# 2  Peter   29    Berlin   62000     Mechanic
# 3  Linda   42    London   85000   Scienticts

# %%
df2.iloc[[2, 3]] ## index loc called location, used when index is diff then number like 0, 1, 2
# Out:
#     Name  Age    City  Salary Designaition
# 2  Peter   29  Berlin   62000     Mechanic
# 3  Linda   42  London   85000   Scienticts

# %%
df2
# Out:
#     Name  Age      City  Salary Designaition
# 0   John   28  New York   65000       Doctor
# 1   Anna   34     Paris   70000          Eng
# 2  Peter   29    Berlin   62000     Mechanic
# 3  Linda   42    London   85000   Scienticts

# %% [markdown]
# #### Creating subset

# %%
df2.loc[[0,1], ["City","Name", "Age"]]
# Out:
#        City  Name  Age
# 0  New York  John   28
# 1     Paris  Anna   34

# %%
df2.loc[[2, 3]][["Name", "Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# #### Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary Designaition
# 0   John   28  New York   65000       Doctor
# 1   Anna   34     Paris   70000          Eng
# 2  Peter   29    Berlin   62000     Mechanic
# 3  Linda   42    London   85000   Scienticts

# %%
df2[df2["Age"] <30]
# Out:
#     Name  Age      City  Salary Designaition
# 0   John   28  New York   65000       Doctor
# 2  Peter   29    Berlin   62000     Mechanic

# %%
df2[(df2["Age"] <30) & (df2["Designaition"]=="Doctor")]
# Out:
#    Name  Age      City  Salary Designaition
# 0  John   28  New York   65000       Doctor
